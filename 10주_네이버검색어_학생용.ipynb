# %% [markdown]
# <a href="https://colab.research.google.com/github/GoldKodo/Data/blob/main/10%EC%A3%BC_%EB%84%A4%EC%9D%B4%EB%B2%84%EA%B2%80%EC%83%89%EC%96%B4_%ED%95%99%EC%83%9D%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q 맷플립 한글 코드 삽입하기

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "클아이언트id"
client_secret = "시크릿코드"

keyword1 = "일본"
keyword2 ="제주도"
startDate='2024-01-01'
endDate='2024-05-11'
device='pc'
url = "https://openapi.naver.com/v1/datalab/search";
timeUnit='month'
keywordGroups=[
    {'groupName':keyword1, 'keywords':[keyword1]},
    {'groupName':keyword2, 'keywords':[keyword2]},
]

url = "https://openapi.naver.com/v1/datalab/search";

response_results_all = pd.DataFrame()

body_dict={} #검색 정보를 저장할 변수
body_dict['startDate']=startDate
body_dict['endDate']=endDate
body_dict['timeUnit']=timeUnit
body_dict['keywordGroups']=keywordGroups
body_dict['device']=device

body=str(body_dict).replace("'",'"') # ' 문자로는 에러가 발생해서 " 로 변환

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2024-01-01","endDate":"2024-05-31","timeUnit":"month","results":[{"title":"일본","keywords":["일본"],"data":[{"period":"2024-01-01","ratio":100},{"period":"2024-02-01","ratio":57.70604},{"period":"2024-03-01","ratio":68.47873},{"period":"2024-04-01","ratio":51.22753},{"period":"2024-05-01","ratio":48.45352}]},{"title":"제주도","keywords":["제주도"],"data":[{"period":"2024-01-01","ratio":87.88908},{"period":"2024-02-01","ratio":70.29592},{"period":"2024-03-01","ratio":81.21547},{"period":"2024-04-01","ratio":82.96032},{"period":"2024-05-01","ratio":82.90442}]}]}

# %% [markdown]
# startData, endData
#
# keywordGroups
#
# age
# gender
#
# https://developers.naver.com/docs/serviceapi/datalab/search/search.md#통합-검색어-트렌드

# %%
import json
result = json.loads(response_body)
print(result)
# Out:
# {'startDate': '2024-01-01', 'endDate': '2024-05-31', 'timeUnit': 'month', 'results': [{'title': '일본', 'keywords': ['일본'], 'data': [{'period': '2024-01-01', 'ratio': 100}, {'period': '2024-02-01', 'ratio': 57.70604}, {'period': '2024-03-01', 'ratio': 68.47873}, {'period': '2024-04-01', 'ratio': 51.22753}, {'period': '2024-05-01', 'ratio': 48.45352}]}, {'title': '제주도', 'keywords': ['제주도'], 'data': [{'period': '2024-01-01', 'ratio': 87.88908}, {'period': '2024-02-01', 'ratio': 70.29592}, {'period': '2024-03-01', 'ratio': 81.21547}, {'period': '2024-04-01', 'ratio': 82.96032}, {'period': '2024-05-01', 'ratio': 82.90442}]}]}

# %%
date = [a['period'] for a in result['results'][0]['data']]
ratio_data1 = [a['ratio'] for a in result['results'][0]['data']]
ratio_data2 = [a['ratio'] for a in result['results'][1]['data']]

# %%
import pandas as pd

df = pd.DataFrame(
    {'date':date,
     'searching_result1':ratio_data1,
      'searching_result2':ratio_data2,}
)
df
# Out:
#          date  searching_result1  searching_result2
# 0  2024-01-01          100.00000           87.88908
# 1  2024-02-01           57.70604           70.29592
# 2  2024-03-01           68.47873           81.21547
# 3  2024-04-01           51.22753           82.96032
# 4  2024-05-01           48.45352           82.90442

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='date', y='searching_result1', data=df,label='일본')
sns.lineplot(x='date', y='searching_result2', data=df,label='제주도')
plt.title('검색어 트렌드')
plt.xticks(rotation=90)
plt.legend()
plt.show()
